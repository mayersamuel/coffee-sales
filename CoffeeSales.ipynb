# %% [markdown]
# # Analysis of students sleep patterns in University
# ### by Jakob Klaffenböck & Samuel Mayer
# ---
#
# This analysis uses the kaggle - "Student Sleep Patterns" dataset.
#
# [](https://link-url-here.org)
#
# Link: https://www.kaggle.com/datasets/arsalanjamal002/student-sleep-patterns
